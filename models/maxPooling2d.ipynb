# %%
from tensorflow.keras.layers import Input, MaxPooling2D
from tensorflow.keras import Model
import numpy as np

# %%
inputs = Input(shape=(5,5,3))
x = MaxPooling2D(pool_size=2)(inputs)
model = Model(inputs, x)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 5, 3)]         0
#
#  max_pooling2d (MaxPooling2D  (None, 2, 2, 3)          0
#  )
#
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
X = np.random.rand(1,5,5,3)
X
# Out:
# array([[[[0.48850216, 0.09321331, 0.85332612],
#          [0.84496756, 0.7795764 , 0.12109799],
#          [0.73028024, 0.30310421, 0.51020707],
#          [0.96140151, 0.59989949, 0.97756324],
#          [0.93625321, 0.34684153, 0.42310131]],
#
#         [[0.27609837, 0.01906993, 0.13781552],
#          [0.58882251, 0.20810185, 0.82620907],
#          [0.74103594, 0.68708322, 0.65134551],
#          [0.31751915, 0.00736138, 0.21706579],
#          [0.33679455, 0.47689636, 0.45021002]],
#
#         [[0.09090417, 0.2587238 , 0.41471808],
#          [0.43759751, 0.96540039, 0.06554565],
#          [0.88061688, 0.97501202, 0.84855213],
#          [0.00548949, 0.58019911, 0.6598191 ],
#          [0.24852607, 0.54914631, 0.063674  ]],
#
#         [[0.02697956, 0.77545233, 0.8692328 ],
#          [0.31050122, 0.11363873, 0.35323089],
#          [0.36624655, 0.65015231, 0.68110343],
#          [0.84333591, 0.95613639, 0.97572016],
#          [0.29138515, 0.84673938, 0.24241197]],
#
#         [[0.55302581, 0.79541176, 0.07496948],
#          [0.37412179, 0.13967356, 0.75689905],
#          [0.50976778, 0.23795235, 0.88867965],
#          [0.62437857, 0.71468241, 0.26784302],
#          [0.04606462, 0.80170968, 0.46812052]]]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 2023-10-22 19:42:47.267039: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# array([[[[0.84496754, 0.7795764 , 0.85332614],
#          [0.9614015 , 0.68708324, 0.97756326]],
#
#         [[0.4375975 , 0.9654004 , 0.8692328 ],
#          [0.8806169 , 0.975012  , 0.97572017]]]], dtype=float32)

# %%
in_json = {
    "in": (X*1000).round().astype(int).flatten().tolist(),
    "out": (y*1000).round().astype(int).flatten().tolist()
}

# %%
import json

# %%
with open("maxPooling2D_input.json", "w") as f:
    json.dump(in_json, f)

# %%
inputs = Input(shape=(10,10,3))
x = MaxPooling2D(pool_size=2, strides=3)(inputs)
model = Model(inputs, x)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10, 10, 3)]       0
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 3)          0
#  2D)
#
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
X = np.random.rand(1,10,10,3)
X
# Out:
# array([[[[0.37512817, 0.5641729 , 0.4974857 ],
#          [0.41538205, 0.47224858, 0.11706032],
#          [0.07640044, 0.34220275, 0.63680247],
#          [0.83220726, 0.92702745, 0.5936356 ],
#          [0.960865  , 0.65484131, 0.90382201],
#          [0.25420919, 0.58229354, 0.51714053],
#          [0.28435198, 0.01320203, 0.34704549],
#          [0.5366293 , 0.91011852, 0.32633545],
#          [0.99100137, 0.2526255 , 0.04232599],
#          [0.39196261, 0.90886648, 0.6597151 ]],
#
#         [[0.29830869, 0.51926462, 0.13915042],
#          [0.4889853 , 0.51424009, 0.75465903],
#          [0.93713835, 0.397958  , 0.20989932],
#          [0.32209555, 0.52508299, 0.63443281],
#          [0.14408686, 0.66008294, 0.13806776],
#          [0.62699816, 0.90600042, 0.56895258],
#          [0.58121376, 0.80103256, 0.44657054],
#          [0.59427662, 0.75233325, 0.57963649],
#          [0.71953207, 0.81024282, 0.21128334],
#          [0.73682019, 0.32007903, 0.67071529]],
#
#         [[0.80006018, 0.11776644, 0.35329049],
#          [0.56318957, 0.07814959, 0.55893929],
#          [0.6583171 , 0.25510277, 0.6436487 ],
#          [0.87175624, 0.8779613 , 0.27569539],
#          [0.72248475, 0.39025583, 0.08435601],
#          [0.16369005, 0.59764421, 0.82081192],
#          [0.56463957, 0.48798142, 0.77631361],
#          [0.6307942 , 0.76449651, 0.11848731],
#          [0.03361245, 0.60884129, 0.62308481],
#          [0.05450976, 0.99955919, 0.85104224]],
#
#         [[0.34374649, 0.12776784, 0.78418845],
#          [0.43181298, 0.74250278, 0.80448435],
#          [0.30220182, 0.21551109, 0.16339278],
#          [0.68197521, 0.89869105, 0.86533282],
#          [0.29757381, 0.71727207, 0.44805748],
#          [0.56151518, 0.57712002, 0.68706843],
#          [0.45412974, 0.9362948 , 0.34822583],
#          [0.56047259, 0.12277996, 0.5023366 ],
#          [0.41692805, 0.7055106 , 0.16808148],
#          [0.99104055, 0.34390128, 0.64835197]],
#
#         [[0.01158626, 0.80397266, 0.12239993],
#          [0.56551958, 0.38561457, 0.87354415],
#          [0.86977938, 0.01654444, 0.14984244],
#          [0.73181502, 0.4821203 , 0.49528692],
#          [0.10936625, 0.83706311, 0.92891834],
#          [0.83026089, 0.48755663, 0.62048641],
#          [0.63684857, 0.31453923, 0.95604607],
#          [0.12678222, 0.43627046, 0.29626141],
#          [0.74729   , 0.23238743, 0.47658838],
#          [0.50673495, 0.68211412, 0.08787302]],
#
#         [[0.51197486, 0.43710453, 0.91323359],
#          [0.01814236, 0.16345393, 0.85949808],
#          [0.6829276 , 0.29987143, 0.09117852],
#          [0.46143246, 0.95382478, 0.36219992],
#          [0.01482736, 0.14046508, 0.87712873],
#          [0.88598586, 0.6276013 , 0.41344697],
#          [0.17294426, 0.66032124, 0.66097391],
#          [0.23200746, 0.17107681, 0.38812876],
#          [0.10606584, 0.88970545, 0.80914975],
#          [0.49200091, 0.66901465, 0.54995615]],
#
#         [[0.89681285, 0.4758079 , 0.64001042],
#          [0.19467218, 0.26358465, 0.74816118],
#          [0.87326546, 0.20928771, 0.83641982],
#          [0.02461293, 0.28929149, 0.39512575],
#          [0.16885368, 0.92957415, 0.76228074],
#          [0.85272569, 0.62753589, 0.99538709],
#          [0.14079888, 0.89010956, 0.14612249],
#          [0.53673487, 0.17782789, 0.87178282],
#          [0.84352221, 0.8385671 , 0.82700386],
#          [0.97036143, 0.3090986 , 0.84921951]],
#
#         [[0.38843924, 0.93957621, 0.43684301],
#          [0.88445531, 0.60651627, 0.36740365],
#          [0.40941211, 0.18899017, 0.59656887],
#          [0.89400746, 0.20580106, 0.50415873],
#          [0.5913926 , 0.88002369, 0.73302724],
#          [0.04508088, 0.95833047, 0.51583369],
#          [0.11842011, 0.4711449 , 0.83241402],
#          [0.90288088, 0.37141538, 0.18550246],
#          [0.67001704, 0.40925315, 0.57717004],
#          [0.24122315, 0.64181833, 0.66151186]],
#
#         [[0.23204307, 0.98373623, 0.19801682],
#          [0.26820398, 0.12769847, 0.23782112],
#          [0.92975541, 0.13423733, 0.13891801],
#          [0.53672017, 0.04206522, 0.87422405],
#          [0.5666062 , 0.14413929, 0.20660685],
#          [0.11504297, 0.71582397, 0.31738761],
#          [0.66674634, 0.36988869, 0.28165541],
#          [0.34138758, 0.94893119, 0.79822198],
#          [0.87085418, 0.41377756, 0.69501997],
#          [0.15644248, 0.77580079, 0.71726857]],
#
#         [[0.4760784 , 0.64495664, 0.25911579],
#          [0.80879442, 0.54131769, 0.21618418],
#          [0.14025275, 0.40313656, 0.94876995],
#          [0.67506045, 0.26935398, 0.06150377],
#          [0.28346581, 0.22987309, 0.36765681],
#          [0.21958624, 0.20597643, 0.93407678],
#          [0.18558843, 0.5443569 , 0.78762915],
#          [0.62086485, 0.76245139, 0.12315994],
#          [0.91905177, 0.41440808, 0.38503421],
#          [0.62550438, 0.45429134, 0.35881556]]]])

# %%
y = model.predict(X)
y
# Out:
# 1/1 [==============================] - 0s 27ms/step
# array([[[[0.4889853 , 0.5641729 , 0.75465906],
#          [0.960865  , 0.92702746, 0.903822  ],
#          [0.5942766 , 0.9101185 , 0.5796365 ]],
#
#         [[0.5655196 , 0.80397266, 0.87354416],
#          [0.73181504, 0.89869106, 0.92891836],
#          [0.63684857, 0.9362948 , 0.95604604]],
#
#         [[0.89681286, 0.9395762 , 0.7481612 ],
#          [0.89400744, 0.92957413, 0.76228076],
#          [0.9028809 , 0.89010954, 0.87178284]]]], dtype=float32)

# %%
in_json = {
    "in": (X*1000).round().astype(int).flatten().tolist(),
    "out": (y*1000).round().astype(int).flatten().tolist()
}

# %%
with open("maxPooling2D_stride_input.json", "w") as f:
    json.dump(in_json, f)
